# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import json
import warnings
warnings.filterwarnings('ignore')
import base64
import io
from matplotlib.pyplot import imread
import codecs

# %%
movie = pd.read_csv("tmdb_5000_movies.csv")
credit = pd.read_csv("tmdb_5000_credits.csv")

# %%
movie.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credit.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movie.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
credit.isnull().sum()
# Out:
# movie_id    0
# title       0
# cast        0
# crew        0
# dtype: int64

# %%
#credit = credit.drop(['title'], axis=1)

movies = movie.drop(['title_x', 'title_y', 'cast_x', 'crew_y', 'cast_y', 'crew_x'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-5ceb4c1f088e> in <module>
#       1 #credit = credit.drop(['title'], axis=1)
#       2
# ----> 3 movies = movie.drop(['title_x', 'title_y', 'cast_x', 'crew_y', 'cast_y', 'crew_x'], axis = 1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
# ...

# %%
print(credit.shape)
print(movie.shape)
# Out:
# (4803, 4)
# (4803, 20)

# %%
movie.describe().transpose()
# Out:
#                count          mean           std  min           25%  \
# budget        4803.0  2.904504e+07  4.072239e+07  0.0  790000.00000
# id            4803.0  5.716548e+04  8.869461e+04  5.0    9014.50000
# popularity    4803.0  2.149230e+01  3.181665e+01  0.0       4.66807
# revenue       4803.0  8.226064e+07  1.628571e+08  0.0       0.00000
# runtime       4801.0  1.068759e+02  2.261193e+01  0.0      94.00000
# vote_average  4803.0  6.092172e+00  1.194612e+00  0.0       5.60000
# vote_count    4803.0  6.902180e+02  1.234586e+03  0.0      54.00000
#
#                        50%           75%           max
# budget        1.500000e+07  4.000000e+07  3.800000e+08
# id            1.462900e+04  5.861050e+04  4.594880e+05
# popularity    1.292159e+01  2.831350e+01  8.755813e+02
# revenue       1.917000e+07  9.291719e+07  2.787965e+09
# runtime       1.030000e+02  1.180000e+02  3.380000e+02
# vote_average  6.200000e+00  6.800000e+00  1.000000e+01
# ...

# %%
credit.describe().transpose()
# Out:
#            count          mean           std  min     25%      50%      75%  \
# movie_id  4803.0  57165.484281  88694.614033  5.0  9014.5  14629.0  58610.5
#
#                max
# movie_id  459488.0

# %%
movies = movie.merge(credit,left_on='id',right_on='movie_id',how='left')
movies = movies.drop(['title_x', 'title_y'], axis = 1)
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# changing the genres column from json to string
movies['genres'] = movies['genres'].apply(json.loads)
for index,i in zip(movies.index,movies['genres']):
    list1 = []
    for j in range(len(i)):
        list1.append((i[j]['name'])) # the key 'name' contains the name of the genre
    movies.loc[index,'genres'] = str(list1)

# changing the keywords column from json to string
movies['keywords'] = movies['keywords'].apply(json.loads)
for index,i in zip(movies.index,movies['keywords']):
    list1 = []
    for j in range(len(i)):
        list1.append((i[j]['name']))
    movies.loc[index,'keywords'] = str(list1)

# changing the cast column from json to string
movies['cast'] = movies['cast'].apply(json.loads)
for index,i in zip(movies.index,movies['cast']):
    list1 = []
    for j in range(len(i)):
        list1.append((i[j]['name']))
    movies.loc[index,'cast'] = str(list1)

# %%
movies = movies[['id','original_title', 'genres','cast','vote_average', 'popularity', 'keywords']]

# %%
movies.head()
# Out:
#        id                            original_title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                               genres  \
# 0  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1                 ['Adventure', 'Fantasy', 'Action']
# 2                   ['Action', 'Adventure', 'Crime']
# 3           ['Action', 'Crime', 'Drama', 'Thriller']
# 4         ['Action', 'Adventure', 'Science Fiction']
#
#                                                 cast  vote_average  \
# 0  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...           7.2
# 1  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...           6.9
# 2  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...           6.3
# ...

# %%
movies.shape
# Out:
# (4803, 7)

# %%
movies.dtypes
# Out:
# id                  int64
# original_title     object
# genres             object
# cast               object
# vote_average      float64
# popularity        float64
# keywords           object
# dtype: object

# %%
movies.columns
# Out:
# Index(['id', 'original_title', 'genres', 'cast', 'vote_average', 'popularity',
#        'keywords'],
#       dtype='object')

# %% [markdown]
# # Performing exploratory data analysis

# %%
# Code to ignore warnings

import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# Code to customise plots

from matplotlib import cycler
colors = cycler('color',
                ['#EE6666', '#5fe8d2', '#9988DD',
                 '#EECC55', '#88BB44', '#FFBBBB'])
plt.rc('axes', facecolor='#E6E6E6', ec='white',
       axisbelow=True, grid=True, prop_cycle=colors)
plt.rc('grid', color='w', linestyle='solid')
plt.rc('xtick', direction='out', color='gray')
plt.rc('ytick', direction='out', color='gray')
plt.rc('patch', edgecolor='#E6E6E6')
plt.rc('lines', linewidth=2)
plt.rcParams["patch.force_edgecolor"] = True

# %% [markdown]
# ## Which are the top genres?

# %%
movies['genres'] = movies['genres'].str.strip('[]').str.replace(' ','').str.replace("'",'')
movies['genres'] = movies['genres'].str.split(',')
movies['genres']
# Out:
# 0       [Action, Adventure, Fantasy, ScienceFiction]
# 1                       [Adventure, Fantasy, Action]
# 2                         [Action, Adventure, Crime]
# 3                   [Action, Crime, Drama, Thriller]
# 4                [Action, Adventure, ScienceFiction]
#                             ...
# 4798                       [Action, Crime, Thriller]
# 4799                               [Comedy, Romance]
# 4800               [Comedy, Drama, Romance, TVMovie]
# 4801                                              []
# 4802                                   [Documentary]
# Name: genres, Length: 4803, dtype: object

# %%
plt.subplots(figsize=(12,10))
l = []
for genre in movies['genres']:
    l.extend(genre)
    
ax = pd.Series(l).value_counts()[:10].sort_values(ascending=True).plot.barh(width=0.9, color=sns.color_palette('hls',15))
for i, count in enumerate(pd.Series(l).value_counts()[:10].sort_values(ascending=True).values): 
    ax.text(.8, i, count,fontsize=12, color='white',weight='bold')

plt.title('Top Genres')
plt.show()

# %% [markdown]
# ## Actors with the most appearances

# %%
movies['cast'] = movies['cast'].str.strip('[]').str.replace(' ','').str.replace("'",'').str.replace('"','')
movies['cast'] = movies['cast'].str.split(',')

# %%
plt.subplots(figsize=(12,10))
cast = []
for i in movies['cast']:
    cast.extend(i)
    
ax = pd.Series(cast).value_counts()[:15].sort_values(ascending=True).plot.barh(width=0.9,color=sns.color_palette('hls',40))
for i, count in enumerate(pd.Series(list1).value_counts()[:15].sort_values(ascending=True).values): 
    ax.text(.8, i, count,fontsize=10,color='white',weight='bold')
    
plt.title('Actors with the most appearances')
plt.show()

# %% [markdown]
# ## Most popular movies in each genre

# %%
m = movies

m = m.explode('genres')
m.explode('genres')
# Out:
#           id                            original_title          genres  \
# 0      19995                                    Avatar          Action
# 0      19995                                    Avatar       Adventure
# 0      19995                                    Avatar         Fantasy
# 0      19995                                    Avatar  ScienceFiction
# 1        285  Pirates of the Caribbean: At World's End       Adventure
# ...      ...                                       ...             ...
# 4800  231617                 Signed, Sealed, Delivered           Drama
# 4800  231617                 Signed, Sealed, Delivered         Romance
# 4800  231617                 Signed, Sealed, Delivered         TVMovie
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew     Documentary
#
#                                                    cast  vote_average  \
# ...

# %% [markdown]
# Animation

# %%
m.loc[m['genres'] == 'Animation'].sort_values(by = ['popularity'], ascending = False).head(3)
# Out:
#          id original_title     genres  \
# 546  211672        Minions  Animation
# 88   177572     Big Hero 6  Animation
# 124  109445         Frozen  Animation
#
#                                                   cast  vote_average  \
# 546  [SandraBullock, JonHamm, MichaelKeaton, Alliso...           6.4
# 88   [ScottAdsit, RyanPotter, DanielHenney, T.J.Mil...           7.8
# 124  [KristenBell, IdinaMenzel, JonathanGroff, Josh...           7.3
#
#      popularity                                           keywords
# 546  875.581305  ['assistant', 'aftercreditsstinger', 'duringcr...
# 88   203.734590  ['brother brother relationship', 'hero', 'tale...
# 124  165.125366  ['queen', 'musical', 'princess', 'betrayal', '...

# %% [markdown]
# Comedy

# %%
m.loc[m['genres'] == 'Comedy'].sort_values(by = ['popularity'], ascending = False).head(3)
# Out:
#          id original_title  genres  \
# 546  211672        Minions  Comedy
# 788  293660       Deadpool  Comedy
# 88   177572     Big Hero 6  Comedy
#
#                                                   cast  vote_average  \
# 546  [SandraBullock, JonHamm, MichaelKeaton, Alliso...           6.4
# 788  [RyanReynolds, MorenaBaccarin, EdSkrein, T.J.M...           7.4
# 88   [ScottAdsit, RyanPotter, DanielHenney, T.J.Mil...           7.8
#
#      popularity                                           keywords
# 546  875.581305  ['assistant', 'aftercreditsstinger', 'duringcr...
# 788  514.569956  ['anti hero', 'mercenary', 'marvel comic', 'su...
# 88   203.734590  ['brother brother relationship', 'hero', 'tale...

# %% [markdown]
# Romance

# %%
m.loc[m['genres'] == 'Romance'].sort_values(by = ['popularity'], ascending = False).head(3)
# Out:
#           id original_title   genres  \
# 809       13   Forrest Gump  Romance
# 1337    8966       Twilight  Romance
# 81    102651     Maleficent  Romance
#
#                                                    cast  vote_average  \
# 809   [TomHanks, RobinWright, GarySinise, MykeltiWil...           8.2
# 1337  [KristenStewart, RobertPattinson, BillyBurke, ...           5.8
# 81    [AngelinaJolie, ElleFanning, SharltoCopley, Sa...           7.0
#
#       popularity                                           keywords
# 809   138.133331  ['vietnam veteran', 'hippie', 'mentally disabl...
# 1337  127.084938  ['soulmates', 'vampire', 'forbidden love', 'im...
# 81    110.620647  ['fairy tale', 'villain', 'sleeping beauty', '...

# %% [markdown]
# Thriller

# %%
m.loc[m['genres'] == 'Thriller'].sort_values(by = ['popularity'], ascending = False).head(3)
# Out:
#          id                  original_title    genres  \
# 127   76341              Mad Max: Fury Road  Thriller
# 28   135397                  Jurassic World  Thriller
# 82   119450  Dawn of the Planet of the Apes  Thriller
#
#                                                   cast  vote_average  \
# 127  [TomHardy, CharlizeTheron, NicholasHoult, Hugh...           7.2
# 28   [ChrisPratt, BryceDallasHoward, IrrfanKhan, Vi...           6.5
# 82   [AndySerkis, JasonClarke, GaryOldman, KeriRuss...           7.3
#
#      popularity                                           keywords
# 127  434.278564  ['future', 'chase', 'post-apocalyptic', 'dysto...
# 28   418.708552  ['monster', 'dna', 'tyrannosaurus rex', 'veloc...
# 82   243.791743  ['leader', 'colony', 'post-apocalyptic', 'dyst...

# %% [markdown]
# Science Fiction

# %%
m.loc[m['genres'] == 'ScienceFiction'].sort_values(by = ['popularity'], ascending = False).head(3)
# Out:
#          id           original_title          genres  \
# 95   157336             Interstellar  ScienceFiction
# 94   118340  Guardians of the Galaxy  ScienceFiction
# 127   76341       Mad Max: Fury Road  ScienceFiction
#
#                                                   cast  vote_average  \
# 95   [MatthewMcConaughey, JessicaChastain, AnneHath...           8.1
# 94   [ChrisPratt, ZoeSaldana, DaveBautista, VinDies...           7.9
# 127  [TomHardy, CharlizeTheron, NicholasHoult, Hugh...           7.2
#
#      popularity                                           keywords
# 95   724.247784  ['saving the world', 'artificial intelligence'...
# 94   481.098624  ['marvel comic', 'spaceship', 'space', 'outer ...
# 127  434.278564  ['future', 'chase', 'post-apocalyptic', 'dysto...
